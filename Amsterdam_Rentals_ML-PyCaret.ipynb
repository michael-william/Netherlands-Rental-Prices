# %% [markdown]
# <font size = 40 color=darkgreen>Dutch Rental Prices</font><br>
# *Both my friends and myself have often asked the question, 'How much rent could I charge for my apartment?' The question becomes very complex as we start assuming that location, size, amenities, furnished, and many more attributes need to be considered when deciding on a rental price. My goal for this project is to build a model that will weigh all the attributes available using data from a popular rental website in the Netherlands, Kamernet. <BR>
# *Creating a regression model to predict the rental prices in the Netherlands using data from kamernet.nl*<br>
# **Steps:**<br>
# 1. Importing libraries and reading data
# 2. EDA and re-shaping data for ML pre-processing
# 3. PyCaret setup
# 4. Adjust base data, repeat compare and create steps

# %% [markdown]
# # <font color=teal>Import data</font>

# %%
# Data manipulation
import pandas as pd
import numpy as np

# ML libraries
import pycaret.regression as py
from pycaret.regression import *

# Options for pandas
pd.options.display.max_columns
pd.options.display.max_rows = 30

# Visualizations
from matplotlib import pyplot as plt
import seaborn as sns
import missingno as msno
import chart_studio.plotly as pl
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode

# %%
# Reading json data from Kamernet

#Git
source = 'https://github.com/michael-william/Netherlands-Rental-Prices/raw/master/properties-trim.json'
df=pd.read_json(source, lines=True)

# %% [markdown]
# # <font color=teal>EDA and reshaping data</font>

# %% [markdown]
# > **<font color=brown>Overview</font>**
# > 1. Dropping non-needed columns
# > 2. Missing values
# > 3. Cardinality of categorical values

# %%
# Creating copy of main df
data = df

# %%
# Viewing first 2 lines of the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12830 entries, 0 to 12829
# Data columns (total 61 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   _id                          12830 non-null  object
#  1   externalId                   12830 non-null  object
#  2   areaRaw                      12830 non-null  object
#  3   areaSqm                      12830 non-null  int64
#  4   city                         12830 non-null  object
#  5   coverImageUrl                12830 non-null  object
#  6   crawlStatus                  12830 non-null  object
#  7   crawledAt                    12830 non-null  object
#  8   datesPublished               12830 non-null  object
#  9   firstSeenAt                  12830 non-null  object
#  10  furnish                      12830 non-null  object
#  11  lastSeenAt                   12830 non-null  object
#  12  latitude                     12830 non-null  float64
#  13  longitude                    12830 non-null  float64
#  14  postalCode                   12830 non-null  object
#  15  postedAgo                    12830 non-null  object
#  16  propertyType                 12830 non-null  object
#  17  rawAvailability              12830 non-null  object
#  18  rent                         12830 non-null  int64
#  19  rentDetail                   12830 non-null  object
#  20  rentRaw                      12830 non-null  object
#  21  source                       12830 non-null  object
#  22  title                        12830 non-null  object
#  23  url                          12830 non-null  object
#  24  additionalCosts              4912 non-null   float64
#  25  additionalCostsRaw           12749 non-null  object
#  26  deposit                      7032 non-null   float64
#  27  depositRaw                   12749 non-null  object
#  28  descriptionNonTranslated     12749 non-null  object
#  29  descriptionNonTranslatedRaw  12749 non-null  object
#  30  descriptionTranslated        12749 non-null  object
#  31  descriptionTranslatedRaw     12749 non-null  object
#  32  detailsCrawledAt             12830 non-null  object
#  33  energyLabel                  12749 non-null  object
#  34  gender                       12749 non-null  object
#  35  internet                     12749 non-null  object
#  36  isRoomActive                 12749 non-null  object
#  37  kitchen                      12749 non-null  object
#  38  living                       12749 non-null  object
#  39  matchAge                     12749 non-null  object
#  40  matchAgeBackup               12749 non-null  object
#  41  matchCapacity                12749 non-null  object
#  42  matchGender                  12749 non-null  object
#  43  matchGenderBackup            12749 non-null  object
#  44  matchLanguages               12749 non-null  object
#  45  matchStatus                  12749 non-null  object
#  46  matchStatusBackup            12749 non-null  object
#  47  pageDescription              12749 non-null  object
#  48  pageTitle                    12749 non-null  object
#  49  pets                         12749 non-null  object
#  50  registrationCost             3667 non-null   float64
#  51  registrationCostRaw          12749 non-null  object
#  52  roommates                    12749 non-null  object
#  53  shower                       12749 non-null  object
#  54  smokingInside                12749 non-null  object
#  55  toilet                       12749 non-null  object
#  56  userDisplayName              12749 non-null  object
#  57  userId                       12749 non-null  float64
#  58  userLastLoggedOn             12749 non-null  object
#  59  userMemberSince              12749 non-null  object
#  60  userPhotoUrl                 12749 non-null  object
# dtypes: float64(6), int64(2), object(53)
# memory usage: 6.0+ MB

# %% [markdown]
# ## <font color=brown>Dropping columns with +50% nulls</font>

# %%
data = data.drop(['deposit', 'additionalCostsRaw', 'additionalCosts', 'registrationCost'], axis=1)

# %% [markdown]
# ## **<font color=brown>Dropping columns</font>**

# %%
# inspection of the following columns shows them to be irrelevant or repeats of other columns 
data = data.drop(['_id','externalId','coverImageUrl','crawlStatus', 'crawledAt', 'datesPublished', 'url', 'source',
              'descriptionNonTranslated','descriptionNonTranslatedRaw','descriptionTranslated',
              'descriptionTranslatedRaw', 'detailsCrawledAt', 'pageDescription', 'pageTitle','userDisplayName',
              'userId','firstSeenAt','lastSeenAt','rentDetail','userLastLoggedOn','userMemberSince','userPhotoUrl', 
              'areaRaw','rentRaw','registrationCostRaw','depositRaw',"matchAge","matchAgeBackup",
              "matchCapacity","matchGender","matchGenderBackup","matchLanguages","matchStatus","matchStatusBackup", 
              'postedAgo', 'rawAvailability', 'gender', 'title', 'postalCode','isRoomActive', 'city'], axis=1)

# %%
# converting 'roommates' feature to 'int' and creating a new binary feature called 'shared'
data['roommates'] = data.roommates.replace(to_replace='None', value=0)
data['roommates'] = data.roommates.replace(to_replace='More than 8', value=9)
data['roommates'] = data.roommates.replace(to_replace='Unknown', value=0)
data['roommates'] = data.roommates.replace(to_replace='nan', value=0)
data['roommates'] = data.roommates.fillna(0)
data['roommates'] = data.roommates.astype('int')
data['shared'] = [1 if x>"yes" else "no" for x in data.roommates]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12830 entries, 0 to 12829
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   areaSqm        12830 non-null  int64
#  1   furnish        12830 non-null  object
#  2   latitude       12830 non-null  float64
#  3   longitude      12830 non-null  float64
#  4   propertyType   12830 non-null  object
#  5   rent           12830 non-null  int64
#  6   energyLabel    12749 non-null  object
#  7   internet       12749 non-null  object
#  8   kitchen        12749 non-null  object
#  9   living         12749 non-null  object
#  10  pets           12749 non-null  object
#  11  roommates      12830 non-null  int64
#  12  shower         12749 non-null  object
#  13  smokingInside  12749 non-null  object
#  14  toilet         12749 non-null  object
#  15  shared         12830 non-null  int64
# dtypes: float64(2), int64(4), object(10)
# memory usage: 1.6+ MB

# %%
# dropping rows with nulls to save on preprocessing time
data = data.dropna()

# %%
# viewing cardinality of remaining columns
data.nunique()
# Out:
# areaSqm           196
# furnish             4
# latitude         7991
# longitude        8003
# propertyType        5
# rent              750
# energyLabel         8
# internet            3
# kitchen             4
# living              4
# pets                3
# roommates          10
# shower              3
# smokingInside       3
# toilet              3
# shared              2
# dtype: int64

# %%
# dropping columns due to high cardinality and thinking that new 'shared' column will help supplement
data.drop(['roommates','energyLabel'], axis=1, inplace=True)

# %%
# dropping other columns to reduce feature size and final application input
data.drop(['internet', 'pets', 'smokingInside', ], inplace=True, axis=1)

# %% [markdown]
# # <font color=teal>PyCaret setup and model creation</font>

# %% [markdown]
# ## **<font color=brown>Setup</font>**

# %%
# setting up pycaret with 'rent'as target
exp_clf = py.setup(data, target = 'rent')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow0_col1" class="data row0 col1" >5861</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow3_col1" class="data row3 col1" >(12749, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow6_col1" class="data row6 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow10_col1" class="data row10 col1" >(12749, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow11_col1" class="data row11 col1" >(8924, 27)</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow12_col1" class="data row12 col1" >(3825, 27)</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53clevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_e0f43b36_c1ba_11ea_bbc1_3c15c2e6b53crow18_col1" class="data row18 col1" >None</td>

# %% [markdown]
# ## **<font color=brown>Comparing models</font>**

# %%
py.compare_models()
# Out:
# <style  type="text/css" >
#     #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53c th {
#           text-align: left;
#     }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow0_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow0_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow1_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow1_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow2_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow2_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow2_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow3_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow3_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow3_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow3_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow4_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow4_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow5_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow5_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow6_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow6_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow7_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow7_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow8_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow8_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow9_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow9_col4 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow10_col0 {
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ca9e726_c1bb_11ea_bbc1_3c15c2e6b53crow10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_

# %% [markdown]
# ## **<font color=brown>Creating model</font>**

# %%
# the Random Forrest had the lowest MAE which is most relevant for this project
rf = py.create_model('rf')
# Out:
#            MAE         MSE      RMSE      R2   RMSLE    MAPE
# 0     106.4793  36242.2172  190.3739  0.8077  0.3064  0.7296
# 1     109.5858  42059.4862  205.0841  0.8450  0.2352  0.1744
# 2     106.7214  37067.4396  192.5291  0.8269  0.3283  0.7251
# 3     119.4900  64040.8296  253.0629  0.7506  0.4285  1.6758
# 4     105.3030  35754.2478  189.0879  0.7847  0.4227  1.4497
# 5     112.9726  48366.4062  219.9236  0.7158  0.4111  2.4656
# 6     111.0865  69524.2590  263.6745  0.6803  0.3059  0.5752
# 7     104.6658  35140.7318  187.4586  0.8428  0.3357  0.7312
# 8     107.7356  33397.0432  182.7486  0.8311  0.2383  0.1823
# 9     104.7139  28917.0499  170.0501  0.8554  0.3307  1.0232
# Mean  108.8754  43050.9711  205.3993  0.7940  0.3343  0.9732
# SD      4.4083  12890.2595   29.3612  0.0569  0.0658  0.6747

# %%
# creating a 'bagged' version of the model to see if the results are boosted
rf_bagged = py.ensemble_model(rf)
# Out:
#            MAE         MSE      RMSE      R2   RMSLE    MAPE
# 0     108.2500  34882.7173  186.7692  0.8149  0.3056  0.7159
# 1     112.0243  41152.1529  202.8599  0.8483  0.2363  0.1797
# 2     108.5070  34430.2815  185.5540  0.8392  0.3386  0.8813
# 3     121.1184  58950.1415  242.7965  0.7705  0.4318  1.7805
# 4     106.0746  30298.6333  174.0650  0.8176  0.4304  1.7055
# 5     113.3562  46368.2551  215.3329  0.7275  0.4121  2.5748
# 6     110.9038  66625.9160  258.1200  0.6937  0.3028  0.5738
# 7     105.0071  33432.8485  182.8465  0.8505  0.3388  0.7892
# 8     109.4236  31914.7229  178.6469  0.8386  0.2392  0.1878
# 9     107.1616  29767.4083  172.5323  0.8512  0.3356  1.0975
# Mean  110.1827  40782.3077  199.9523  0.8052  0.3371  1.0486
# SD      4.3987  12117.5052   28.3086  0.0531  0.0672  0.7229

# %%
# analyzing residuals of the model vs the predicted value
py.plot_model(rf)

# %%
# viewing the impact of features on the model
py.interpret_model(rf)

# %% [markdown]
# # <font color=teal>Adjust base data and re-run</font>

# %% [markdown]
# ## **<font color=brown>Drop low importance features</font>**

# %%
# new setup with low importance feature columns removed
clf2 = py.setup(data, target='rent', ignore_features=['toilet','shower', 'living', 'kitchen'])
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow0_col1" class="data row0 col1" >8046</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow3_col1" class="data row3 col1" >(12749, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow6_col1" class="data row6 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow10_col1" class="data row10 col1" >(12749, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow11_col1" class="data row11 col1" >(8924, 13)</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow12_col1" class="data row12 col1" >(3825, 13)</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53clevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_ce0f8d44_c1c0_11ea_bbc1_3c15c2e6b53crow18_col1" class="data row18 col1" >None</td>

# %% [markdown]
# ## **<font color=brown>Compare models</font>**

# %%
# comparing models of new setup
py.compare_models()
# Out:
# <style  type="text/css" >
#     #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53c th {
#           text-align: left;
#     }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow0_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow0_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow1_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow1_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow2_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow2_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow2_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow2_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow3_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow3_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow4_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow4_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow5_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow5_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow6_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow6_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow7_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow7_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow7_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow8_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow8_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow9_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow9_col4 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow10_col0 {
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2e857062_c1c1_11ea_bbc1_3c15c2e6b53crow10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_

# %% [markdown]
# ## **<font color=brown>Create models</font>**

# %%
data['shared'] = ["yes" if x>0 else "no" for x in data.shared]

# %%
# the Random Forrest model was again the best with some improved metrics
rf2 = py.create_model('rf')
# Out:
# IntProgress(value=0, description='Processing: ', max=14)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               13:11:02
# Status     . . . . . . . . . . . . . . . . . .   Fitting Fold 9 of 10
# ETC        . . . . . . . . . . . . . . . . . .  6.0 Seconds Remaining
#         MAE         MSE      RMSE      R2   RMSLE    MAPE
# 0  103.6356  29004.5611  170.3073  0.8387  0.3455  0.8843
# 1  110.9518  69506.8096  263.6414  0.7133  0.3689  1.0968
# 2  109.4709  44071.9636  209.9332  0.7648  0.3256  0.7714
# 3  113.4019  43355.7995  208.2206  0.7915  0.2540  0.1947
# 4  103.2564  30310.1425  174.0981  0.8596  0.2816  0.5376
# 5  109.3502  33933.5019  184.2105  0.8096  0.3607  1.0649
# 6  108.9189  49837.5136  223.2432  0.7843  0.3426  0.9592
# 7  111.9183  41019.2821  202.5322  0.8052  0.3663  1.3124

# %%
# viewing the residuals of the model vs the preidtced value
py.plot_model(rf2)

# %%
# viewing impact of feature on the model
py.interpret_model(rf2)

# %% [markdown]
# ## **<font color=brown>Predict on hold-out set</font>**

# %%
# using the hold-out set from setup to predict rent with model
rf2_predict = py.predict_model(rf2)
# Out:
#                      Model       MAE         MSE      RMSE      R2   RMSLE  \
# 0  Random Forest Regressor  103.2168  32337.5885  179.8266  0.8427  0.3326
#
#      MAPE
# 0  1.1932

# %% [markdown]
# ## **<font color=brown>Finalize and save model</font>**

# %%
# finalizing the model to adjust for over/under fitting
final_rf2 = py.finalize_model(rf2)
final_rf2
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=8046, verbose=0, warm_start=False)

# %%
# saving the model
py.save_model(final_rf2, "dutch_pycaret_rf")
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
# saving the experiment
py.save_experiment("exp_dutch_pycaret_rf")
# Out:
# Experiment Succesfully Saved

# %%
# final dataframe
data.drop(['toilet', 'shower', 'living', 'kitchen'], axis=1).columns
# Out:
# Index(['areaSqm', 'furnish', 'latitude', 'longitude', 'propertyType', 'rent',
#        'shared'],
#       dtype='object')
